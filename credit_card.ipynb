# %%
import numpy as np
import pandas as pd
df = pd.read_csv('BankChurners.csv')

# %% [markdown]
# #### Mean of column names
# CLIENTNUM : Client number. Unique identifier for the customer holding the account\
# Attrition_Flag : Internal event (customer activity) variable\
# Customer_Age : Customer's Age in Years\
# Gender : M=Male, F=Female\
# Dependent_count : Number of dependents\
# Education_Level : Educational Qualification of the account holder\
# Marital_Status : Married, Single, Divorced, Unknown\
# Income_Category : Annual Income Category of the account holder\
# Card_Category : Type of Card (Blue, Silver, Gold, Platinum)\
# Months_on_book : Period of relationship with bank\
# Total_Relationship_Count : Total no. of products held by the customer\
# Months_Inactive_12_mon : No. of months inactive in the last 12 months\
# Contacts_Count_12_mon : No. of Contacts in the last 12 months\
# Credit_Limit : Credit Limit on the Credit Card\
# Total_Revolving_Bal : Total Revolving Balance on the Credit Card\
# Avg_Open_To_Buy : Open to Buy Credit Line (Average of last 12 months)\
# Total_Amt_Chng_Q4_Q1 : Change in Transaction Amount (Q4 over Q1)\
# Total_Trans_Amt : Total Transaction Amount (Last 12 months)\
# Total_Trans_Ct : Total Transaction Count (Last 12 months)\
# Total_Ct_Chng_Q4_Q1 : Change in Transaction Count (Q4 over Q1)\
# Avg_Utilization_Ratio : Average Card Utilization Ratio

# %%
# 最後兩欄無意義，先刪除
df = df.iloc[:,0:21]
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# 檢查是否有缺失值

# %%
# True: 有空值  False: 無空值
df.isnull().any()
# Out:
# CLIENTNUM                   False
# Attrition_Flag              False
# Customer_Age                False
# Gender                      False
# Dependent_count             False
# Education_Level             False
# Marital_Status              False
# Income_Category             False
# Card_Category               False
# Months_on_book              False
# Total_Relationship_Count    False
# Months_Inactive_12_mon      False
# Contacts_Count_12_mon       False
# Credit_Limit                False
# Total_Revolving_Bal         False
# Avg_Open_To_Buy             False
# Total_Amt_Chng_Q4_Q1        False
# Total_Trans_Amt             False
# Total_Trans_Ct              False
# Total_Ct_Chng_Q4_Q1         False
# Avg_Utilization_Ratio       False
# dtype: bool

# %% [markdown]
# 檢查是否有重複的編號

# %%
# false代表無重複
df['CLIENTNUM'].duplicated().any()
# Out:
# False

# %%
df.drop(columns=['CLIENTNUM'],inplace=True)

# %%
df
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# 將Attrition_Flag中的Existing Customer改成1，Attrited Customer改成0

# %%
df['Attrition_Flag'].unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df['Attrition_Flag'] = df['Attrition_Flag'].map({'Existing Customer':1, 'Attrited Customer':0})

# %%
df['Attrition_Flag'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# 計算繼續留存客戶的比例
df['Attrition_Flag'].sum()/df.shape[0]
# Out:
# 0.8393403772094401

# %% [markdown]
# 兩個類別的人數差異大，需要特別注意

# %%
df.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag                int64
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %% [markdown]
# Gender, Education_Level, Marital_Status, Income_Category, Income_Category為類別型態

# %%
# 將gender改成 M => 1  F => 0
df['Gender'] = df['Gender'].map({'M':1, 'F':0})

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# 將類別資料(字串)轉換成one hot encoder
df_dum = pd.get_dummies(df)

# %%
df_dum.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Education_Level_College', 'Education_Level_Doctorate',
#        'Education_Level_Graduate', 'Education_Level_High School',
#        'Education_Level_Post-Graduate', 'Education_Level_Uneducated',
#        'Education_Level_Unknown', 'Marital_Status_Divorced',
#        'Marital_Status_Married', 'Marital_Status_Single',
#        'Marital_Status_Unknown', 'Income_Category_$120K +',
#        'Income_Category_$40K - $60K', 'Income_Category_$60K - $80K',
#        'Income_Category_$80K - $120K', 'Income_Category_Less than $40K',
#        'Income_Category_Unknown', 'Card_Category_Blue', 'Card_Category_Gold',
# ...

# %% [markdown]
# #### K-Nearest Neighbours

# %%
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix


# 建立X, y
X = df_dum.drop(columns=['CLIENTNUM','Attrition_Flag'])
y = df_dum['Attrition_Flag']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

model = neighbors.KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)


X_test = scaler.transform(X_test)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
num_correct_samples = accuracy_score(y_test, y_pred, normalize=False)
con_matrix = confusion_matrix(y_test, y_pred)

print('number of correct sample: {}'.format(num_correct_samples))
print('accuracy: {}'.format(accuracy))
print('confusion matrix: \n{}'.format(con_matrix))
# Out:
# number of correct sample: 1736
# accuracy: 0.8568608094768015
# confusion matrix:
# [[ 124  230]
#  [  60 1612]]

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.datasets import load_iris
from sklearn import tree

# 建立X, y
X = df_dum.drop(columns=['Attrition_Flag'])
y = df_dum['Attrition_Flag']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

model = RandomForestClassifier(max_depth=5, n_estimators=1000,n_jobs=-1)
#model = RandomForestClassifier(max_depth=6, n_estimators=1000)
model.fit(X_train, y_train)

X_test = scaler.transform(X_test)
y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
num_correct_samples = accuracy_score(y_test, y_pred, normalize=False)
con_matrix = confusion_matrix(y_test, y_pred)

print('number of correct sample: {}'.format(num_correct_samples))
print('accuracy: {}'.format(accuracy))
print('con_matrix: \n{}'.format(con_matrix))
# Out:
# number of correct sample: 1848
# accuracy: 0.912142152023692
# con_matrix:
# [[ 154  145]
#  [  33 1694]]

# %%
# 將模型存成pickle檔
import pickle
pickle.dump(model, open('RF_credit.pkl','wb'))

# %%
# demo
# input data use get_dummies()
import pandas as pd
df = pd.DataFrame({'cat':['a','b','c','d'],'val':[1,2,5,10]})
df1 = pd.get_dummies(pd.DataFrame({'cat':['a'],'val':[1]}))
dummies_frame = pd.get_dummies(df)
df1.reindex(columns = dummies_frame.columns, fill_value=0)
# Out:
#    val  cat_a  cat_b  cat_c  cat_d
# 0    1      1      0      0      0

# %%
col = ['Customer_Age', 'Gender', 'Dependent_count',
       'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
       'Education_Level_College', 'Education_Level_Doctorate',
       'Education_Level_Graduate', 'Education_Level_High School',
       'Education_Level_Post-Graduate', 'Education_Level_Uneducated',
       'Education_Level_Unknown', 'Marital_Status_Divorced',
       'Marital_Status_Married', 'Marital_Status_Single',
       'Marital_Status_Unknown', 'Income_Category_$120K +',
       'Income_Category_$40K - $60K', 'Income_Category_$60K - $80K',
       'Income_Category_$80K - $120K', 'Income_Category_Less than $40K',
       'Income_Category_Unknown', 'Card_Category_Blue', 'Card_Category_Gold',
       'Card_Category_Platinum', 'Card_Category_Silver']

# %%
d = {
 "Customer_Age": 30,
 "Gender": 1,
 "Dependent_count": 3,
 "Education_Level": "Graduate",
 "Marital_Status": "Married",
 "Income_Category": "Less than $40K",
 "Card_Category": "Blue",
 "Months_on_book": 35,
 "Total_Relationship_Count": 3,
 "Months_Inactive_12_mon": 2,
 "Contacts_Count_12_mon": 2,
 "Credit_Limit": 4700,
 "Total_Revolving_Bal": 1200,
 "Avg_Open_To_Buy": 3400,
 "Total_Amt_Chng_Q4_Q1": 1.5,
 "Total_Trans_Amt": 1800,
 "Total_Trans_Ct": 42,
 "Total_Ct_Chng_Q4_Q1": 0.85,
 "Avg_Utilization_Ratio": 0.145}

# %%
# 建立新的資料
input_df = pd.DataFrame(d,index=['input'])
input_df
# Out:
#        Customer_Age  Gender  Dependent_count Education_Level Marital_Status  \
# input            30       1                3        Graduate        Married
#
#       Income_Category Card_Category  Months_on_book  Total_Relationship_Count  \
# input  Less than $40K          Blue              35                         3
#
#        Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# input                       2                      2          4700
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# input                 1200             3400                   1.5
#
#        Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# input             1800              42                 0.85
#
#        Avg_Utilization_Ratio
# input                  0.145

# %%
input_dum = pd.get_dummies(input_df)
input_dum = input_dum.reindex(columns = col, fill_value=0)

# %%
model.predict(input_dum)
# Out:
# array([1], dtype=int64)

# %%
# 測試模型的pickle
with open('GBRmodel.pkl', 'rb') as f:
    model_load = pickle.load(f)

y_pred = model_load.predict(X_test)
r2_score(y_test, y_pred)
